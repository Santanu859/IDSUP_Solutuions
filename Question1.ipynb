# %%
#1

import random
d1 = []
for i in range(1000):
    d1.append(random.randint(60, 70))
print(d1)
# Out:
# [68, 65, 70, 60, 62, 63, 66, 62, 63, 62, 62, 64, 61, 70, 63, 70, 60, 70, 64, 66, 69, 70, 69, 64, 60, 60, 66, 61, 60, 62, 69, 66, 66, 60, 63, 62, 63, 70, 70, 63, 64, 61, 61, 70, 62, 62, 68, 66, 68, 65, 61, 60, 70, 62, 68, 63, 68, 67, 63, 68, 64, 67, 65, 60, 62, 63, 62, 63, 67, 61, 66, 64, 63, 61, 65, 63, 66, 69, 67, 70, 66, 60, 65, 63, 65, 69, 62, 66, 69, 64, 70, 62, 66, 60, 69, 67, 60, 63, 60, 68, 66, 60, 65, 68, 63, 62, 61, 63, 65, 70, 70, 60, 66, 67, 63, 64, 69, 68, 70, 68, 61, 69, 61, 64, 60, 69, 69, 65, 66, 66, 61, 65, 62, 62, 61, 69, 69, 63, 68, 67, 61, 63, 67, 68, 70, 66, 60, 63, 70, 67, 68, 61, 68, 69, 68, 66, 70, 69, 68, 61, 67, 63, 63, 66, 66, 70, 63, 68, 67, 63, 67, 68, 61, 62, 69, 64, 69, 69, 69, 63, 63, 64, 64, 61, 69, 68, 66, 65, 64, 68, 69, 66, 68, 65, 65, 70, 64, 67, 68, 69, 66, 65, 64, 61, 70, 68, 62, 61, 65, 68, 64, 60, 64, 63, 66, 66, 63, 62, 66, 66, 67, 64, 67, 69, 69, 62, 66, 69, 60, 61, 60, 60, 67, 63, 65, 67, 68, 70, 61, 66, 70, 68, 65, 64, 64, 68, 70, 68, 61, 7
# ...

# %%
import pandas as pd

df = pd.DataFrame(d1)
df
# Out:
#       0
# 0    68
# 1    65
# 2    70
# 3    60
# 4    62
# ..   ..
# 995  60
# 996  66
# 997  63
# 998  60
# 999  66
#
# [1000 rows x 1 columns]

# %%
# 2
mean = df.mean()
print("Mean value: ",mean)
# Out:
# Mean value:  0    65.135
# dtype: float64

# %%
std = df.std()
print("Standard-deviation: ",std)
# Out:
# Standard-deviation:  0    3.132825
# dtype: float64

# %%
# 3
import matplotlib.pyplot as plt

plt.hist(d1 , bins=10, color='green', edgecolor='black', linewidth=1.2)
plt.title('Histogram of 1000 Random Values between 60 and 70')
plt.show()

# %%
#4 and #5
import numpy as np
sample=[]
Smean=[]
for j in range(30):
    for i in range(30):
        j=random.choice(d1)
        sample.append(j)
    s=np.mean(sample)
    Smean.append(s)
print(Smean)
# Out:
# [65.23333333333333, 65.28333333333333, 65.05555555555556, 64.78333333333333, 64.99333333333334, 65.13333333333334, 65.16190476190476, 65.1, 65.05185185185185, 65.1, 65.1969696969697, 65.21944444444445, 65.24871794871795, 65.26666666666667, 65.27777777777777, 65.26041666666667, 65.2607843137255, 65.22592592592592, 65.19824561403509, 65.19166666666666, 65.1984126984127, 65.23181818181818, 65.18840579710145, 65.20555555555555, 65.21066666666667, 65.2025641025641, 65.19012345679012, 65.15714285714286, 65.16206896551724, 65.20222222222222]

# %%
#6
import numpy as np
sample=[]
Smean=[]
for j in range(400):
    for i in range(50):
        j=random.choice(d1)
        sample.append(j)
    s=np.mean(sample)
    Smean.append(s)
print(Smean)
# Out:
# [65.06, 65.05, 65.06666666666666, 64.985, 64.956, 64.94666666666667, 64.97142857142858, 65.0075, 65.0111111111111, 64.972, 65.01454545454546, 65.03666666666666, 64.98, 64.97, 64.98133333333334, 64.9975, 64.9929411764706, 65.03222222222222, 65.04631578947368, 65.028, 65.03238095238095, 65.0709090909091, 65.08521739130435, 65.07166666666667, 65.0944, 65.12307692307692, 65.12222222222222, 65.15785714285714, 65.15034482758621, 65.16, 65.15741935483871, 65.161875, 65.18181818181819, 65.16529411764706, 65.18285714285715, 65.18722222222222, 65.1827027027027, 65.18315789473684, 65.16461538461539, 65.148, 65.1419512195122, 65.14190476190477, 65.14697674418605, 65.13363636363637, 65.11288888888889, 65.1304347826087, 65.13659574468085, 65.12958333333333, 65.13673469387756, 65.1388, 65.13725490196079, 65.13846153846154, 65.13320754716982, 65.14814814814815, 65.15890909090909, 65.15321428571428, 65.14842105263158, 65.14448275862068, 65.14406779661017, 65.14033333333333, 65.13147540983607, 65.1348
# ...

# %%
#7
plt.hist(Smean , bins=10, color='green', edgecolor='black', linewidth=1.2)

plt.show()

# %%
#8
print("Sample mean: ",np.mean(Smean))
# Out:
# Sample mean:  65.08923795810784

# %%
print('Standard deviation: ', np.std(Smean))
# Out:
# Standard deviation:  0.03329998805968894

# %%
import math
print(std/math.sqrt(30))
# Out:
# 0    0.571973
# dtype: float64
